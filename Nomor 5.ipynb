# %% [markdown]
# # 5. Buatlah model regresi untuk memprediksi data dari variabel profil.

# %% [markdown]
# # # Simple Linear regression

# %% [markdown]
# Pada soal ini, variabel yang akan di

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

# %%
#Load dataset
data = pd.read_csv("dataset_superstore_simple.csv")
data
# Out:
#             order_id  order_date customer_id    segment         category  \
# 0     CA-2016-152156   11/8/2016    CG-12520   Consumer        Furniture
# 1     CA-2016-152156   11/8/2016    CG-12520   Consumer        Furniture
# 2     CA-2016-138688   6/12/2016    DV-13045  Corporate  Office Supplies
# 3     US-2015-108966  10/11/2015    SO-20335   Consumer        Furniture
# 4     US-2015-108966  10/11/2015    SO-20335   Consumer  Office Supplies
# ...              ...         ...         ...        ...              ...
# 9983  CA-2014-110422   1/21/2014    TB-21400   Consumer        Furniture
# 9984  CA-2017-121258   2/26/2017    DB-13060   Consumer        Furniture
# 9985  CA-2017-121258   2/26/2017    DB-13060   Consumer       Technology
# 9986  CA-2017-121258   2/26/2017    DB-13060   Consumer  Office Supplies
# 9987  CA-2017-119914    5/4/2017    CC-12220   Consumer  Office Supplies
#
#      sub_category     sales  quantity    profit
# ...

# %%
data.describe()
# Out:
#              sales     quantity       profit
# count  9988.000000  9988.000000  9988.000000
# mean    221.952598     3.789147    27.105341
# std     514.818043     2.225586   186.115016
# min       0.444000     1.000000 -3839.990400
# 25%      17.248000     2.000000     1.730250
# 50%      54.376000     3.000000     8.652800
# 75%     209.814000     5.000000    29.345400
# max    9892.740000    14.000000  4946.370000

# %% [markdown]
# # Membuat regresi

# %%
#membuat regresi
#independen variabel pada percobaan kali ini adalah variabel profit
x1 = data["profit"]

#variabel depended pada percobaan kali ini adalah sales
y = data["sales"]

# %% [markdown]
# # Mengeksplore data

# %%
plt.scatter(x1,y)
plt.xlabel('profit',fontsize=20)
plt.ylabel('sales',fontsize=20)
plt.show()

# %% [markdown]
# # Tabel regresi

# %%
x = sm.add_constant(x1)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.209
# Model:                            OLS   Adj. R-squared:                  0.209
# Method:                 Least Squares   F-statistic:                     2639.
# Date:                Tue, 01 Feb 2022   Prob (F-statistic):               0.00
# Time:                        21:18:41   Log-Likelihood:                -75364.
# No. Observations:                9988   AIC:                         1.507e+05
# Df Residuals:                    9986   BIC:                         1.507e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        187.6738      4.630     40.535      0.000     178.598     196.749
# ...

# %%
plt.scatter(x1,y)
#yhat = x1(data size) * profit + 
yhat = x1*1.2647 + 187.6738
fig = plt.plot(x1,yhat, lw=4, c='orange', label ='regression line')
plt.xlabel('Size', fontsize = 20)
plt.ylabel('Price', fontsize = 20)
plt.show()
